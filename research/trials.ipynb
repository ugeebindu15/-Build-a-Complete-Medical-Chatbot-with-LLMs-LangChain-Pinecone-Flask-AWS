# %%
print("ok")
# Out:
# ok

# %%
# %pwd
# Out:
# '/Users/ugeebindu/Downloads/-Build-a-Complete-Medical-Chatbot-with-LLMs-LangChain-Pinecone-Flask-AWS/research'

# %%
from langchain.document_loaders import PyPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# Extract text from PDF files
def load_pdf_Files(data):
    loader = DirectoryLoader(
        data,
        glob="*.pdf",
        loader_cls=PyPDFLoader
    )

    documents=loader.load()
    return documents

# %%
extracted_data = load_pdf_Files("data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 extracted_data = load_pdf_Files("data")
#
# Cell In[16], line 9, in load_pdf_Files(data)
#       2 def load_pdf_Files(data):
#       3     loader=DirectoryLoader(
#       4         data,
#       5         glob="*.pdf",
#       6         loader_cls=PyPDFLoader
#       7     )
# ----> 9     documents=loader.load()
#      10     return documents
#
# File /usr/local/anaconda3/envs/medibot/lib/python3.10/site-packages/langchain_community/document_loaders/directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File /usr/local/anaconda3/envs/medibot/lib/python3.10/site-packages/langchain_community/document_loaders/directory.py:123, in DirectoryLoader.lazy_load(self)
#     121 p = Path(self.path)
#     122 if not p.exists():
# --> 123     raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     124 if not p.is_dir():
#     125     raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# FileNotFoundError: Directory not found: 'data'
